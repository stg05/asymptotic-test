# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = (8, 5)

# %% [markdown]
# # Bruteforce

# %%
df = pd.read_csv("bruteforce.csv", delimiter = ';')
df['time'] = df.apply(lambda x: x[1::5].median(), axis=1)

df
# Out:
#        size  time1  time2  time3  time4  time5   time
# 0      1000      0      0      0      0      0    0.0
# 1      2000      1      1      1      1      1    1.0
# 2      3000      2      2      2      2      2    2.0
# 3      4000      3      3      3      3      3    3.0
# 4      5000      4      4      4      3      4    4.0
# ..      ...    ...    ...    ...    ...    ...    ...
# 145  146000    131    118    118    145    123  131.0
# 146  147000    129    132    131    133    131  129.0
# 147  148000    132    133    128    131    126  132.0
# 148  149000    121    120    128    120    120  121.0
# 149  150000    127    129    134    128    122  127.0
#
# [150 rows x 7 columns]

# %%
k=0.00085
ls = np.linspace(0, 150000, 100)
plt.xlabel(r'Number of elements')
plt.ylabel(r'Time of operation, s')
plt.plot(ls, k*ls, '--k', lw=1)
plt.plot(df['size'], df['time'], 'or', ms=1)
plt.title('Bruteforce, 1000 iterations: $\mathbf{O(n)}$')
# Out:
# Text(0.5, 1.0, 'Bruteforce, 1000 iterations: $\\mathbf{O(n)}$')

# %% [markdown]
# #
